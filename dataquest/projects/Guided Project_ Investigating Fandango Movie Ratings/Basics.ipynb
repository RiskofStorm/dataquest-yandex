# %% [markdown]
# ### Investigating Fandango Movie Ratings

# %% [markdown]
# Investigating Fandango's love to increase films rating that will sell via his own casses.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
fan = pd.read_csv("fandango_score_comparison.csv")
mov = pd.read_csv("movie_ratings_16_17.csv")

# %%
cols = ["FILM", "Fandango_Stars", "Fandango_Ratingvalue", "Fandango_votes", "Fandango_Difference"]
fan_iso = fan[cols]
mov_iso = mov[["movie","year", "fandango"]]

# %%
fan.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm         ...           IMDB_norm  RT_norm_round  \
# ...

# %%
mov.head()
# Out:
#                      movie  year  metascore  imdb  tmeter  audience  fandango  \
# 0      10 Cloverfield Lane  2016         76   7.2      90        79       3.5
# 1                 13 Hours  2016         48   7.3      50        83       4.5
# 2      A Cure for Wellness  2016         47   6.6      40        47       3.0
# 3          A Dog's Purpose  2017         43   5.2      33        76       4.5
# 4  A Hologram for the King  2016         58   6.1      70        57       3.0
#
#    n_metascore  n_imdb  n_tmeter  n_audience  nr_metascore  nr_imdb  \
# 0         3.80    3.60      4.50        3.95           4.0      3.5
# 1         2.40    3.65      2.50        4.15           2.5      3.5
# 2         2.35    3.30      2.00        2.35           2.5      3.5
# 3         2.15    2.60      1.65        3.80           2.0      2.5
# 4         2.90    3.05      3.50        2.85           3.0      3.0
#
#    nr_tmeter  nr_audience
# 0        4.5          4.0
# 1        2.5          4.0
# ...

# %%
import urllib

url = "https://github.com/fivethirtyeight/data/blob/master/fandango/README.md"
fan_read = urlib.open(url).readlines()

url2 = "https://github.com/mircealex/Movie_ratings_2016_17/blob/master/README.md"
mov_read = urlib.open(url2).readlines()

print(fan_read)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-13-61d85655debd> in <module>()
#       2
#       3 url = "https://github.com/fivethirtyeight/data/blob/master/fandango/README.md"
# ----> 4 fan_read = urlib.open(url).readlines()
#       5
#       6 url2 = "https://github.com/mircealex/Movie_ratings_2016_17/blob/master/README.md"
#
# NameError: name 'urlib' is not defined

# %%
print(mov_read)

# %%
fandango_2016 = mov[mov['year'] == 2016].copy()
fandango_2016['year'].value_counts()
fandango_2015 = fam[fan['Year'] == '2015'].copy()
fandango_2015['Year'].value_counts()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-14-4be5bd1efaca> in <module>()
#       1 fandango_2016 = mov[mov['year'] == 2016].copy()
#       2 fandango_2016['year'].value_counts()
# ----> 3 fandango_2015 = fam[fan['Year'] == '2015'].copy()
#       4 fandango_2015['Year'].value_counts()
#
# NameError: name 'fam' is not defined
