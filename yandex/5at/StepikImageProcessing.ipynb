# %%
from skimage.io import imsave, imshow, imread
from __future__ import division
import itertools
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/storm/anaconda3/envs/py27/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['imshow', 'imread', 'imsave']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
img = imread("https://stepik.org/media/attachments/lesson/58180/img.png")
img.shape[1]
# Out:
# 419

# %%
img = imread("https://stepik.org/media/attachments/lesson/58180/tiger-color.png")
mid = [int(img.shape[i]/2.) for i in range(2)]
img[mid[0]][mid[1]] = [102, 204, 102]
# imsave("tiger-color-green-pixel.png")

# %%
imshow(img)

# %%
np.array_equal(img,imread("https://stepik.org/media/attachments/lesson/58180/tiger-color.png"))
# Out:
# False

# %%
img.shape
# Out:
# (601, 801, 3)

# %%
img2 = imread("https://stepik.org/media/attachments/lesson/58180/tiger-gray.png")
chek = imread('https://stepik.org/media/attachments/lesson/58180/tiger-pink.png')

y,x = img2.shape[0]//2 , img2.shape[1]//2

img2[y-3:y+4, x-7:x+8 ] = [255, 192, 203]
# np.array_equal(img2,chek)
imsave(img2)
# Out:
# False

# %%
img2[y-3:y4, x-7:x+8 ] = [255,0,255]

# %%
plt.figure(dpi=350)
imshow(img2)
plt.show()
plt.figure(dpi=350)
imshow(chek)

# %%
# Out:
# False

# %%
imshow(img2[y:y1+50, x:x1+50])
