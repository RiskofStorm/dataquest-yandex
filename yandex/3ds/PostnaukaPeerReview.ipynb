# %% [markdown]
# # Тематическая модель [Постнауки](http://postnauka.ru)
# ## Peer Review (optional)

# %% [markdown]
# В этом задании мы применим аппарат тематического моделирования к коллекции текстовых записей видеолекций, скачанных с сайта Постнаука. Мы будем визуализировать модель и создавать прототип тематического навигатора по коллекции. В коллекции 1728 документов, размер словаря - 38467 слов. Слова лемматизированы, то есть приведены к начальной форме, с помощью программы [mystem](https://tech.yandex.ru/mystem/), коллекция сохранена в [формате vowpal wabbit](http://docs.bigartm.org/en/latest/formats.html). В каждой строке до первой черты записана информация о документе (ссылка на страницу с лекцией), после первой черты следует описание документа. Используются две модальности - текстовая ("text") и модальность авторов ("author"); у каждого документа один автор.

# %% [markdown]
# Для выполнения задания понадобится библиотека [BigARTM](http://docs.bigartm.org). В демонстрации показан пример использования библиотеки версии 0.7.4, на сайте предлагается скачивать версию 0.8.0. В новой версии изменены принципы работы со словарями: они вынесены в отдельный класс (пример в [Release Notes](http://docs.bigartm.org/en/stable/release_notes/python.html)). Строить модель и извлекать ее параметры нужно так же, как показано в демонстрации. Вы можете использовать [предыдущий релиз](http://bigartm.readthedocs.io/en/v0.7.6/download.html) или [новый релиз](http://docs.bigartm.org/en/latest/download.html) на ваше усмотрение.
#
# Спецификации всех функций вы можете смотреть на странице [Python API](http://bigartm.readthedocs.io/en/stable/python_interface.html).

# %%
import artm

# %%
from matplotlib import pyplot as plt
import seaborn
# %matplotlib inline
seaborn.set_style("whitegrid", {'axes.grid' : False})

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##### Считывание данных

# %% [markdown]
# Создайте объект класса artm.BatchVectorizer, который будет ссылаться на директорию с пакетами данных (батчами). Чтобы библиотека могла преобразовать текстовый файл в батчи, создайте пустую директорию и укажите ее название в параметре target_folder. Размер батча для небольших коллекций (как наша) не важен, вы можете указать любой.

# %%
# Ваш код
batch_vectorizer = artm.BatchVectorizer(data_path="lectures.txt", data_format="vowpal_wabbit", target_folder="post_batches")

# %% [markdown]
# ##### Инициализация модели

# %% [markdown]
# Создайте объект класса artm.Model с 30 темами, именами тем, указанными ниже и единичными весами обеих модальностей. Количество тем выбрано не очень большим, чтобы вам было удобнее работать с темами. На этой коллекции можно строить и большее число тем, тогда они будут более узко специализированы.

# %%
T = 30   # количество тем
topic_names=["sbj"+str(i) for i in range(T-1)]+["bcg"]
# Ваш код

model = artm.ARTM(num_topics=T, topic_names=topic_names, class_ids={'text':1, 'author':1}, reuse_theta=True, 
                  cache_theta=True, seed=1, num_document_passes=1)

# %% [markdown]
# Мы будем строить 29 предметных тем и одну фоновую.
#
# Соберите словарь с помощью метода gather_dictionary и инициализируйте модель, указав random_seed=1. Обязательно укажите свое название словаря, оно понадобится при добавлении регуляризаторов.

# %%
# Ваш код
dictionary = artm.Dictionary("dictionary")
dictionary.gather(batch_vectorizer.data_path)

# %%
model.initialize('dictionary')

# %% [markdown]
# ##### Добавление score

# %% [markdown]
# Создайте два измерителя качества artm.TopTokensScore - по одному для каждой модальности; количество токенов 15. Названия для score придумайте самостоятельно.

# %%
# Ваш код
model.scores.add(artm.TopTokensScore(name="top words",  num_tokens=15, class_id="text"))
model.scores.add(artm.TopTokensScore(name="top authors",  num_tokens=15, class_id="author"))

# %% [markdown]
# ##### Построение модели

# %% [markdown]
# Мы будем строить модель в два этапа: сначала добавим сглаживающий регуляризатор фоновой темы и настроим параметры модели, затем - добавим разреживающий регуляризатор предметрых тем и выполним еще несколько итераций. Так мы сможем получить наиболее чистые от фоновых слов предметные темы. Сглаживающий и разреживающий регуляризаторы задаются одним и тем же классом artm.SmoothSparsePhiRegularizer: если коэффициент tau положительный, то регуляризатор будет сглаживающий, если отрицательный - разреживающий.
#
# Если вы хотите подробнее разобраться, как выполняется регуляризация тематической модели в BigARTM, вы можете прочитать [статью](https://s3-eu-west-1.amazonaws.com/artm/voron-potap14artm-rus.pdf), раздел 4.

# %% [markdown]
# Добавьте сглаживающий регуляризатор с коэффициентом tau = 1e5, указав название своего словаря в dictionary, модальность текста в class_ids и тему "bcg" в topic_names.

# %%
# Ваш код
model.regularizers.add(artm.SmoothSparsePhiRegularizer(name="SparsePhi", tau =1e5, 
                                                       dictionary=dictionary, class_ids="text", topic_names="bcg"))

# %% [markdown]
# Выполните 30 итераций по коллекции (num_collection_passes), количество внутренних итераций установите равным 1. Используйте метод fit_offline модели.

# %%
# Ваш код
model.num_document_passes = 1
model.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=30)

# %% [markdown]
# Добавьте разреживающий регуляризатор с коэффициентом tau=-1e5, указав название своего словаря, модальность текста в class_ids и все темы "sbjX" в topic_names.

# %%
# Ваш код
model.regularizers.add(artm.SmoothSparsePhiRegularizer(name="SparcePhi", tau=-1e5, 
                                                         dictionary=dictionary, class_ids="text", topic_names="sbjX"))

# %% [markdown]
# Выполните еще 15 проходов по коллекции.

# %%
# Ваш код
model.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=15)

# %% [markdown]
# ##### Интерпретация тем

# %% [markdown]
# Используя созданные score, выведите топы слов и топы авторов в темах. Удобнее всего выводить топ слов каждой темы с новой строки, указывая название темы в начале строки, и аналогично с авторами.

# %%
# Ваш код
authors = model.score_tracker['top authors'].last_tokens
tokens = model.score_tracker['top words'].last_tokens

for topic in model.topic_names:
    print  topic + ": " + ", ".join([i for i in authors[topic]])
    print
# Out:
# sbj0: Дмитрий_Казаков, Михаил_Данилов, Валерий_Рубаков, Сергей_Майоров, Виктор_Брагута, Павел_Пахлов, Игорь_Волобуев, Илья_Щуров, Лев_Беклемишев, Анатолий_Лиходед, Эдуард_Боос, Сергей_Троицкий, Алексей_Старобинский, Лев_Дудко, Армен_Сергеев
#
# sbj1: Артем_Оганов, Валерий_Фокин, Дмитрий_Паращук, Валентин_Ненайденко, Владимир_Пудалов, Дмитрий_Гольберг, Евгений_Гудилин, Иван_Сорокин, Валентин_Крапошин, Дмитрий_Клинов, Евгений_Антипов, Владимир_Комлев, Ильдар_Габитов, Алексей_Кавокин, Пётр_Образцов
#
# sbj2: Кирилл_Мартынов, Алексей_Юдин, Александр_Филиппов, Фёдор_Успенский, Иван_Ладынин, Андрей_Лукашов, Татьяна_Смоктунович, Михаил_Бойцов, Дина_Гусейнова, Ольга_Тогоева, Рафаэль_Арутюнян, Руслан_Хестанов, Олег_Хлевнюк, Владимир_Малахов, Николай_Дронин
#
# sbj3: Виктор_Вахштайн, Наталья_Ростиславлева, Максим_Демин, Александр_Пиперски, Татьяна_Клячко, Григорий_Крейдлин, Владимир_Миронов, Борис_Миркин, Анатолий_Баранов, Илья_Иткин, Ян_Левченко, Кристофер_Уиншип, Алексей_Котов, Дмитрий_Баюк, Дмитрий_Балалыкин
#
# sbj4: Филипп_Хайтович, Владимир_Спиридонов, Мария_Фаликман, Надежда_Онипенко, Александр_Каплан, Ольга_Сварник, Мария_Майофис, Вера_Подлесская, Александр_Лазуткин, Наталья_Спасская, Жанна_Резникова, Ноам_Хомский, Михаил_Алексеевский, Екатерина_Лютикова, Джефф_Лихтман
#
# sbj5: Гасан_Гусейнов, Кирилл_Еськов, Владимир_Емельянов, Андрей_Иванцов, Андрей_Журавлев, Аскольд_Иванчик, Григорий_Бондаренко, Ольга_Тогоева, Николай_Дронин, Александр_Воеводский, Олег_Ауров, Ян_Левченко, Фёдор_Успенский, Мария_Майофис, Алексей_Козырев
#
# sbj6: Борис_Морозов, Алексей_Бартошевич, Леонид_Иомдин, Ольга_Брилева, Дмитрий_Добровольский, Павел_Руднев, Игорь_Исаев, Илья_Виньковецкий, Оксана_Запорожец, Анастасия_Лопухина, Александр_Пиперски, Алина_Бодрова, Михаил_Алексеевский, Павел_Нерлер_(Полян), Анатолий_Гершман
#
# sbj7: Станислав_Дробышевский, Александр_Поддьяков, Екатерина_Ларионова, Елена_Браун, Дмитрий_Жуков, Валентина_Харитонова, Мария_Медникова, Григорий_Юдин, Марк_Харрисон, Михаил_Соколов, Дмитрий_Беляев, Наталья_Харламенкова, Андрей_Летаров, Михаил_Алексеевский, Варвара_Веденина
#
# sbj8: Дмитрий_Дождев, Александр_Марей, Сергей_Неклюдов, Татьяна_Бобровникова, Денис_Новак, Дмитрий_Полдников, Фёдор_Успенский, Алексей_Шмелев, Павел_Нерлер_(Полян), Андрей_Чабовский, Сет_Ллойд, ПостНаука, Ольга_Вайнштейн, Андрей_Глазовский, Виктор_Задков
#
# sbj9: Егор_Задереев, Алексей_Алексеев, Сергей_Румянцев, Руслан_Смелянский, Светлана_Боринская, Александр_Аузан, Сергей_Саложин, Марина_Корсакова-Крейн, Антон_Чугунов, Денис_Сивков, Зоя_Зорина, Марина_Бутовская, Александр_Петренко, Павел_Умрюхин, Станислав_Клименко
#
# sbj10: Елизавета_Бонч-Осмоловская, Алла_Ножевникова, Дмитрий_Лось, Сергей_Киселев, Андрей_Цатурян, Александр_Марков, Станислав_Дробышевский, Владимир_Муронец, Дмитрий_Громов, Светлана_Дедыш, Николай_Пименов, Зоригто_Намсараев, Юлия_Краус, Сергей_Наугольных, Евгений_Магид
#
# sbj11: Мария_Фаликман, Кирилл_Титаев, Константин_Анохин, Павел_Балабан, Игорь_Уточкин, Сергей_Соколовский, Мира_Бергельсон, Алексей_Созинов, Алексей_Моисеев, Виктор_Мурогов, Виталий_Дунин-Барковский, Андрей_Коротаев, Ави_Лёб, Евгений_Николаев, Галина_Зеленина
#
# sbj12: Илья_Женин, Фёдор_Успенский, Алексей_Миллер, Игорь_Данилевский, Кирилл_Кочегаров, Елена_Уханова, Сергей_Серёгичев, Александр_Лаврентьев, Алексей_Малашенко, Андрей_Виноградов, Владимир_Петрухин, Ольга_Эдельман, Екатерина_Лямина, Ахмет_Ярлыкапов, Александр_Дмитриев
#
# sbj13: Виктор_Вахштайн, Виталий_Куренной, ПостНаука, Елена_Брызгалина, Дмитрий_Рогозин, Александр_Гофман, Ольга_Артёмова, Ольга_Малинова, Владимир_Малахов, Михаил_Маяцкий, Павел_Руднев, Наталья_Смолянская, Виктор_Полтерович, Сергей_Гуриев, Сергей_Афонцев
#
# sbj14: Сергей_Попов, Алексей_Расторгуев, Ольга_Сильченко, Дмитрий_Вибе, Анатолий_Засов, Владимир_Сурдин, Дмитрий_Титов, Александр_Шацкий, Наталья_Новикова, Александр_Слободкин, Роман_Рафиков, Сергей_Писарев, Сергей_Таскаев, Алексей_Старобинский, Эмиль_Ахмедов
#
# sbj15: Фуад_Алескеров, Алексей_Белянин, Владимир_Гимпельсон, Василий_Жарков, Алексей_Кондрашов, Сергей_Бобылев, Наталья_Зубаревич, Василий_Ключарев, Ксения_Паниди, Антон_Суворов, Татьяна_Клячко, Андрей_Чабовский, Ян_Левченко, Александр_Тхостов, Константин_Воронцов
#
# sbj16: Михаил_Соколов, Ольга_Гулевич, Мария_Падун, Татьяна_Ребеко, Наталья_Кисельникова, Наталья_Харламенкова, Ольга_Исупова, Максим_Киселев, Махзарин_Банаджи, Александр_Войскунский, Виктор_Вахштайн, Арсений_Хитров, Татьяна_Котова, Александр_Филиппов, Александр_Каменский
#
# sbj17: Михаил_Бурцев, Александр_Беленький, Александр_Сафонов, Илья_Шкредов, Станислав_Протасов, Дмитрий_Ветров, Григорий_Кабатянский, Даниэль_Сельва, Сезар_Идальго, Мануэль_Маццара, Макс_Тегмарк, Михаил_Киселев, Александр_Жданов, Петр_Дружинин, Джозеф_Браун
#
# sbj18: Дмитрий_Беляев, Кирилл_Бабаев, Георгий_Старостин, Марк_Ульянов, Владимир_Плунгян, Анна_Дыбо, Дмитрий_Худяков, Сергей_Арутюнов, Алексей_Лебедев, Борис_Иомдин, Галина_Зеленина, Алексей_Маслов, Евгений_Рогожин, Галина_Ершова, Александр_Мещеряков
#
# sbj19: Евгений_Шеваль, Константин_Северинов, Максим_Франк-Каменецкий, Михаил_Гельфанд, Антон_Буздин, Виталий_Кушниров, Сергей_Киселев, Сергей_Науменко, Александр_Апт, Иван_Воробьев, Андрей_Летаров, Георгий_Базыкин, Роман_Ефремов, Александр_Габибов, Питер_Лэнсдорп
#
# sbj20: Владимир_Белотелов, Алексей_Акимов, Алексей_Рубцов, Михаил_Киселев, Владимир_Мележик, Юджин_Ползик, Андрей_Савельев-Трофимов, Сергей_Демокритов, Пётр_Турчин, Владимир_Шалаев, Алексей_Желтиков, Владимир_Кузнецов, Виталий_Пальчиков, Василий_Климов, Иван_Луковников
#
# sbj21: Алексей_Козырев, Иван_Болдырев, Сергей_Неклюдов, Александр_Доброхотов, Александра_Архипова, Петр_Резвых, Мария_Неклюдова, Александр_Павлов, Катерина_Поливанова, Михаил_Алексеевский, Алексей_Руткевич, Кирилл_Разлогов, Владимир_Кантор, Ольга_Вайнштейн, Андрей_Кофман
#
# sbj22: Александр_Марей, Дмитрий_Бовыкин, Олег_Хлевнюк, Павел_Уваров, Кирилл_Соловьев, Игорь_Курукин, Олег_Мельник, Илья_Кукулин, Андрей_Зорин, Алина_Бодрова, Михаил_Алексеевский, Ольга_Вайнштейн, Дмитрий_Дагаев, Мохамад_Кассаб, Екатерина_Лямина
#
# sbj23: Вера_Мильчина, Ирина_Бёме, Анна_Соколова, Олег_Будницкий, Борис_Колоницкий, Михаил_Бойцов, Михаил_Маяцкий, Александр_Каменский, Дэвид_Кайзер, Людмила_Новикова, Варвара_Веденина, Алексей_Киличенков, Архат_Абжанов, Пол_Грегори, Эдуард_Пройдаков
#
# sbj24: Алексей_Муравьёв, Владимир_Плунгян, Олег_Воскобойников, Андрей_Кибрик, Мария_Штейнман, Олег_Лекманов, Игорь_Исаев, Петр_Аркадьев, Владимир_Беликов, Светлана_Бурлак, Нина_Сумбатова, Илья_Иткин, Максим_Кронгауз, Варвара_Добровольская, Ирина_Левонтина
#
# sbj25: Эмиль_Ахмедов, Алексей_Семихатов, Андрей_Лосев, Павел_Лушников, Игорь_Петров, Владимир_Редько, Александр_Кислов, Илья_Щуров, Владимир_Каганский, Александр_Филиппов, Виктор_Авдеев, Сергей_Ландо, Сергей_Нечаев, Александра_Скрипченко, Сергей_Наугольных
#
# sbj26: Раиса_Кирсанова, Сергей_Пекарский, Светлана_Евграфова, Александр_Дьяконов, Борис_Миркин, Анатолий_Баранов, Григорий_Крейдлин, Мария_Фаликман, Ян_Левченко, Денис_Загарин, Андрей_Шевельков, Наталья_Савва, Николай_Дронин, Андрей_Журавлев, Александр_Пиперски
#
# sbj27: Сергей_Попов, Анатолий_Засов, Валерий_Сулейманов, Михаил_Ревнивцев, Дмитрий_Горбунов, Олег_Верходанов, Виктория_Битюкова, Сергей_Блинников, Александр_Потехин, Антон_Бирюков, Сергей_Троицкий, Эрик_Мазур, Уолтер_Льюин, Сергей_Шишкин, Мел_Сигел
#
# sbj28: Александр_Павлов, Ивар_Максутов, Светлана_Баньковская, Павел_Соколов, Николай_Плотников, Елена_Вишленкова, Елизавета_Ривкина, Михаил_Эпштейн, Екатерина_Щербакова, Алексей_Козырев, Владимир_Каганский, Александр_Львовский, Антон_Бернс, Дина_Гусейнова, Александр_Парфенов
#
# bcg: Петр_Федичев, Александр_Жаворонков, Ярослав_Ашихмин, Юрий_Яшков, Александр_Васильев, Вера_Ижевская, Михаил_Пантелеев, Алексей_Чжао, Иван_Оселедец, Рауль_Гайнетдинов, Максим_Таланов, Дмитрий_Дорохов, Владимир_Ковальзон, Алиса_Вячеславова, Алишер_Тураев

# %%
for topic in model.topic_names:
    print topic + ": ",
    for word in tokens[topic]:
        print word,
    print
# Out:
# sbj0:  частица быть что это этот который взаимодействие кварк теория весь как они симметрия такой физика
# sbj1:  быть это этот что материал который как мочь для такой структура очень температура они при
# sbj2:  быть что это политический который этот как государство власть тот такой очень для свой все
# sbj3:  что это этот быть который как язык система университет мочь один если такой или знание
# sbj4:  что быть это который этот человек мозг они как такой если мочь слово тот ребенок
# sbj5:  быть что этот это который как они человек миф весь такой время или мир бог
# sbj6:  быть это что который этот как город русский они человек такой очень язык для текст
# sbj7:  это они что быть человек который этот как очень другой мочь самый трудность раса или
# sbj8:  право что быть этот это как который такой римский вещь тот правовой мочь юрист если
# sbj9:  это быть который что этот как или боль мочь человек они очень для когда медицина
# sbj10:  это быть что этот который они как робот год такой очень для мочь какой микроорганизм
# sbj11:  память что быть или как который это этот процесс мочь информация наш они если один
# sbj12:  быть что это который год этот как они свой война тот век русский весь империя
# sbj13:  как это что наука который этот какой рассказывать социальный проблема современный история новый человек понятие
# sbj14:  быть что планета это галактика который звезда этот мочь земля как очень такой дыра они
# sbj15:  что быть этот это который человек мочь решение как они тот очень для если или
# sbj16:  что человек быть это который этот как они другой мочь или тот социальный такой если
# sbj17:  быть что который это этот как сеть для задача мочь такой если данные они компьютер
# sbj18:  это быть который этот что язык как они век письменность город или государство такой слово
# sbj19:  клетка быть что это который этот днк они как ген белок мочь такой молекула для
# sbj20:  это быть этот который что квантовый такой как мочь магнитный поле для очень если один
# sbj21:  быть это что который этот как философия культура она свой философский для другой они век
# sbj22:  быть что это этот революция который год власть как они человек свой тот король политический
# sbj23:  быть что это который они этот война советский год россия как первый очень человек русский
# sbj24:  язык быть это который этот что как они христианский русский другой говорить или культура для
# sbj25:  что это быть теория который этот пространство система как они какой-то один такой если так
# sbj26:  что быть это который как этот слово она или мочь очень такой для они например
# sbj27:  что звезда быть это этот который очень они вселенная излучение как такой нейтронный мочь вещество
# sbj28:  это что быть который этот фильм как они мочь ученый кино роль или книга для
# bcg:  это что быть этот который мочь заболевание человек как или система такой пациент очень если

# %% [markdown]
# В последней теме "bcg" должны находиться общеупотребительные слова.
#
# Важный шаг в работе с тематической моделью, когда речь идет о визуализации или создании тематического навигатора, это именование тем. Понять, о чем каждая тема, можно по списку ее топовых слов. Например, тему
#
#     частица взаимодействие физика кварк симметрия элементарный нейтрино стандартный материя протон бозон заряд масса ускоритель слабый
#
# можно назвать "Физика элементарных частиц".
#
# Дайте названия 29 предметным темам. Если вы не знаете, как назвать тему, назовите ее первым встретившимся в ней существительным, хотя при таком подходе навигатор будет менее информативным. Из названий тем составьте список из 29 строк и запишите го в переменную sbj_topic_labels. В переменной topic_labels будут храниться названия всех тем, включая фоновую.

# %%
sbj_topic_labels = ["Физика элементарных частиц", "материал", "общество", "университет",
                   "физиология", "атеизм", "литература", "произведение", "юриспруденция",
                   "медицина", "биоинформатика", "информатика", "история", "история",
                   "астрономия", "обществознание", "обществознание", "информатика",
                   "история", "биология", "квантовая физика", "философия","история",
                   "история", "культура", "физика", "мотивация", "астрономическая физика", "рецензия", 
                    "биология"]   # запишите названия тем в список
topic_labels = sbj_topic_labels + ["Фоновая тема"]

# %%
len(sbj_topic_labels)
# Out:
# 30

# %% [markdown]
# ##### Анализ тем

# %% [markdown]
# Далее мы будем работать с распределениями тем в документах (матрица $\Theta$) и авторов в темах (одна из двух матриц $\Phi$, соответствующая модальности авторов).
# Создайте переменные, содержащие две этих матрицы, с помощью методов get_phi и get_theta модели. Назовите переменные theta и phi_a. Выведите формы обеих матриц, чтобы понять, по каким осям стоят темы.

# %%
model_artm.theta_columns_naming = "title" # включает именование столбцов Theta их названиями-ссылками, а не внутренними id 
# Ваш код

# %% [markdown]
# Визуализируем фрагмент матрицы $\Theta$ - первые 100 документов (это наиболее простой способ визуально оценить, как темы распределяются в документах). С помощью метода seaborn.heatmap выведите фрагмент theta как изображение. Рекомендация: создайте фигуру pyplot размера (20, 10).

# %%
# Ваш код

# %% [markdown]
# Вы должны увидеть, что фоновая тема имеет большую вероятность в почти каждом документе, и это логично. Кроме того, есть еще одна тема, которая чаще других встречается в документах. Судя по всему, это тема содержит много слов по науку в целом, а каждый документ (видео) в нашей коллекции связан с наукой. Можно (необязательно) дать этой теме название "Наука".
#
# Помимо этих двух тем, фоновой и общенаучной, каждый документ характеризуется малым числом других тем.

# %% [markdown]
# Оценим $p(t)$ - долю каждой темы во всей коллекции. По формуле полной вероятности вычислять эти величины нужно как
# $p(t) = \sum_d p(t|d) p(d)$. Согласно вероятностной модели, $p(d)$ пропорционально длине документа d. Поступим проще: будем полагать, что все документы равновероятны. Тогда оценить $p(t)$ можно, просуммировав $p(t|d)$ по всем документам, а затем разделив полученный вектор на его сумму.
#
# Создайте переменную-датафрейм с T строками, индексированными названиями тем, и 1 столбцом, содержащим оценки $p(t)$. Выведите датафрейм на печать.

# %%
# Ваш код

# %% [markdown]
# Найдите 5 самых распространенных и 3 наименее освещенных темы в коллекции (наибольшие и наименьшие $p(t)$ соответственно), не считая фоновую и общенаучную. Укажите названия, которые вы дали этим темам.

# %% [raw]
# Ваш ответ:
# 5 тем с max p(t):
# 3 темы с min p(t):

# %% [markdown]
# Визуализируйте матрицу $\Phi$ модальности авторов в виде изображения. Рекомендация: установите yticklabels=False в heatmap.

# %%
# Ваш код

# %% [markdown]
# Каждой теме соответствует не очень большое число авторов - матрица достаточно разреженная. Кроме того, некоторые темы имеют доминирующего автора $a$, имеющего большую вероятность $p(a|t)$ - этот автор записал больше всего лекций по теме.

# %% [markdown]
# Будем считать, что автор $a$ значим в теме, если $p(a|t) > 0.01$. Для каждого автора посчитайте, в скольких темах он значим. Найдите авторов-рекордсменов, которые значимы (а значит, читали лекции) в >= 3 темах.

# %% [raw]
# Ваш ответ:
# авторы, значимые в не менее чем 3 темах:

# %% [markdown]
# Большинство авторов значимы в 1 теме, что логично.

# %% [markdown]
# ##### Построение тематической карты авторов

# %% [markdown]
# По сути, в матрице $\Phi$, соответствующей модальности авторов, записаны тематические кластеры авторов. Для любого автора мы можем составить его тематический круг - авторов, разбирающихся в той же теме, что и данный. Интересующиеся слушатели могут попробовать выполнить эту процедуру для ученых, читающих лекции на Постнауке, которых они знают (например, на Постнауке есть лекции с К. В. Воронцовым - лектором текущего модуля :)
#
# Составим карту близости авторов по тематике их исследований. Для этого применим метод понижения размерности MDS к тематическим профилям авторов.
#
# Чтобы получить тематический профиль автора, распределение $p(t|a)$, нужно воспользоваться формулой Байеса:
# $p(t|a) = \frac {p(a|t) p(t)} {\sum_t' p(a|t') p(t')}$. Все необходимые для этого величины у вас есть и записаны в переменных phi и pt.
#
# Передайте матрицу тематических профилей авторов, записанных по строкам, в метод MDS с n_components=2. Используйте косинусную метрику (она хорошо подходит для поиска расстояний между векторами, имеющими фиксированную сумму компонент).

# %%
from sklearn.manifold import MDS
from sklearn.metrics import pairwise_distances

# %%
# Ваш код

# %% [markdown]
# Визуализируйте найденные двумерные представления с помощью функции scatter.

# %%
# Ваш код

# %% [markdown]
# Должно получиться, что некоторые грппы авторов формируют сгустки, которые можно считать тематическими группами авторов.
#
# Раскрасим точки следующим образом: для каждого автора выберем наиболее вероятную для него тему ($\max_t p(t|a)$), и каждой теме сопоставим цвет. Кроме того, добавим на карту имена и фамилии авторов, это можно сделать в цикле по всем точкам с помощью функции plt.annotate, указывая метку точки первым аргументом и ее координаты в аргументе xy. Рекомендуется сделать размер изображения большим, тогда маркеры точек тоже придется увеличить (s=100 в plt.scatter). Изобразите карту авторов и сохраните в pdf-файл с помощью функции plt.savefig.
#
# Метки авторов будут пересекаться. Будет очень хорошо, если вы найдете способ, как этого можно избежать.

# %%
import matplotlib.cm as cm
colors = cm.rainbow(np.linspace(0, 1, T)) # цвета для тем
# Ваш код

# %% [markdown]
# ##### Создание простого тематического навигатора по Постнауке

# %% [markdown]
# Наш тематический навигатор будет для каждой темы показывать ее список слов, а также список релевантных теме документов.
#
# Нам понадобятся распределения $p(d|t)$. По формуле Байеса $p(d|t) = \frac{p(t|d)p(d)}{\sum_{d'}p(t|d')p(d')}$, но поскольку мы считаем документы равновероятными, достаточно разделить каждую строку $\Theta$ на ее сумму, чтобы оценить распределение.
#
# Отсортируйте матрицу $p(d|t)$ по убыванию $p(d|t)$ в каждой теме (то есть построчно). Нам понадобятся индексы наиболее вероятных документов в каждой теме, поэтому используйте функцию argmax.

# %%
# Ваш код

# %% [markdown]
# Создавать навигатор мы будем прямо в jupiter notebook: это возможно благодаря тому факту, что при печати ссылки она автоматически превращается в гиперссылку.

# %%
print "http://yandex.ru"   # получится кликабельная ссылка

# %% [markdown]
# Кроме того, подключив модуль [ipython.core.display](https://ipython.org/ipython-doc/2/api/generated/IPython.core.display.html), можно использовать html-разметку в выводе. Например:

# %%
from IPython.core.display import display, HTML
display(HTML(u"<h1>Заголовок</h1>"))   # также <h2>, <h3>
display(HTML(u"<ul><li>Пункт 1</li><li>Пункт 2</li></ul>"))
display(HTML(u'<font color="green">Зеленый!</font>'))
display(HTML(u'<a href="http://yandex.ru">Еще один вариант вывода ссылки</a>'))

# %% [markdown]
# В цикле для каждой темы выведите ее заголовок, в следующей строке - топ-10 слов темы, затем в виде списка ссылки на 10 наиболее релевантных (по $p(d|t)$) теме документов. Используйте html-разметку. Творчество приветствуется :)

# %%
# Ваш код

# %% [markdown]
# ##### Заключение

# %% [markdown]
# В этом Peer Review мы познакомились с базовыми возможностями библиотеки BigARTM и с методами визуализации тематических моделей. Визуализация тематических моделей - это широкая и активно развивающаяся область научных исследований. Мы рассмотрели только самые простые приемы. Желающие могут попробовать применить [Serendip](http://vep.cs.wisc.edu/serendip/#serendipHero), разработанный в  University of Wisconsin-Madison, к построенной модели. Эта библиотека позволяет максимально полно охарактеризовать темы и написана для языка python.
#
# Сделав задание, вы можете выбрать в навигаторе наиболее интересную для вас тему и посмотреть видеолекции :) На Постнауке очень много интересных материалов.
